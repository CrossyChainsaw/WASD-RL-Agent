# %% [markdown]
# # WASD2
# <img src="WASD2.png" alt="WASD2 Screenshot" width="600">
#
# WASD2 is a game wherein you see a sequence of 2 letters. this makes the game a bit harder since you have to first enter the first letter and then enter the second letter. this introduces a new challenge for the model, remembering its previous action. after trying it out with the resources i used in other challenges i came to the conclusion that i should use different technologies (maybe RNN or LSTM).
#
# with a 3 frame stack model and training for 3000 episodes it does sometimes get good runs, but it still needs a lot of training to be flawless. (Highscore of 44 -> 88 actions correctly in a row)
#
# Also it struggles to get off of score 0 which makes sense, since 1 good action doesnt bring the agent off score 0 instantly, it needs a second good action but it cant seem to figure that out

# %% [markdown]
# installs
# - gymnasium: 0.29.1
# - pygame
# - matplotlib: 3.9.2
# - torch: 2.4.1+cpu
# - torchvision: 0.19.1+cpu
# - torchaudio: 2.4.1+cpu
# - torchsummary

# %%
import gymnasium as gym
import matplotlib
import torch
import torchvision
import torchaudio
import torchsummary

print(gym.__version__)          # 0.29.1
print(matplotlib.__version__)   # 3.9.2
print(torch.__version__)        # 2.4.1
print(torchvision.__version__)  # 0.19.1
print(torchaudio.__version__)   # 2.4.1
# Out:
# 0.29.1
# 3.9.2
# 2.4.1+cpu
# 0.19.1+cpu
# 2.4.1+cpu

# %% [markdown]
# 1. Setup the CNN for Q-Learning

# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque
from torchvision import transforms

STACK_SIZE = 3

# Define the CNN Q-network
class DQNCNN(nn.Module):
    def __init__(self, action_size):
        super(DQNCNN, self).__init__()
        self.conv1 = nn.Conv2d(STACK_SIZE, 64, kernel_size=3, stride=2)  # Using default stride and padding
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)  # Reduces size further

        # Adjust this size based on your calculations
        self.fc1 = nn.Linear(64 * 20 * 20, 512)
        self.fc2 = nn.Linear(512, action_size)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = self.pool(x)  # Apply max pooling to reduce size further
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = torch.relu(self.fc1(x))
        return self.fc2(x)

# %% [markdown]
# 2. Preprocessing Function

# %%
# Preprocess the frames (resize and convert to grayscale)
def preprocess_frame(frame):
    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Grayscale(),  # Convert to grayscale
        transforms.Resize((84, 84)),  # Resize to 84x84
        transforms.ToTensor(),  # Convert to tensor, will have shape [1, 84, 84]
    ])
    return transform(frame).squeeze(0)  # Remove the single channel dimension, resulting in [84, 84]


# Stack 4 frames
def stack_frames(frames):
    return np.stack(frames, axis=0)  # Shape will be [4, 84, 84]

# %% [markdown]
# 3. Experience Replay Buffer

# %%
# Replay buffer to store past experiences
class ReplayBuffer:
    def __init__(self, buffer_size=10000):
        self.memory = deque(maxlen=buffer_size)

    def add(self, experience):
        self.memory.append(experience)

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# 4. DQN Agent

# %%
class DQNAgent:
    def __init__(self, action_size):
        self.action_size = action_size
        self.memory = ReplayBuffer(buffer_size=10000) 
        self.gamma = 0.99  # Discount factor
        self.epsilon = 0.4  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.batch_size = 64
        self.update_frequency = 4

        # Create two networks: one for the current Q-function and one for the target Q-function
        self.q_network = DQNCNN(action_size)
        self.target_network = DQNCNN(action_size)
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=0.0001)

        # Copy weights from the current network to the target network
        self.target_network.load_state_dict(self.q_network.state_dict())

    def select_action(self, state, explore=True):
        # During exploration, select a random action
        if explore and np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        # During exploitation, select the action with the highest Q-value
        state = torch.FloatTensor(state).unsqueeze(0)  # Convert to tensor and add batch dimension
        q_values = self.q_network(state)
        return torch.argmax(q_values).item()

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        minibatch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        # Convert to numpy arrays before converting to tensors
        states = torch.FloatTensor(np.array(states))
        next_states = torch.FloatTensor(np.array(next_states))
        actions = torch.LongTensor(actions)
        rewards = torch.FloatTensor(rewards)
        dones = torch.FloatTensor(dones)

        # Get current Q values
        q_values = self.q_network(states).gather(1, actions.unsqueeze(1)).squeeze(1)

        # Get target Q values
        next_q_values = self.target_network(next_states).max(1)[0]
        target_q_values = rewards + (self.gamma * next_q_values * (1 - dones))

        # Compute loss
        loss = nn.MSELoss()(q_values, target_q_values.detach())
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Update epsilon
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def update_target_network(self):
        self.target_network.load_state_dict(self.q_network.state_dict())

# %% [markdown]
# 5. Initialise Environment

# %%
from WASDEnv import WinFormsGameEnv

# env = gym.make('CartPole-v1', render_mode='rgb_array')
env = WinFormsGameEnv()

# %% [markdown]
# 6. Initialise Agent

# %%
agent = DQNAgent(action_size=env.action_space.n)

# %%
agent

# %% [markdown]
# 7. Training Loop

# %%
# Stack size for CNN input (4 stacked frames)
stack_size = STACK_SIZE
agent.q_network.train()

# Training loop
num_episodes = 2000
for e in range(num_episodes):
    state_stack = deque(maxlen=stack_size)
    state, info = env.reset()
    
    # Initialize frame stack with initial frame
    frame = preprocess_frame(env.render())
    for _ in range(stack_size):
        state_stack.append(frame)

    done = False
    total_reward = 0
    while not done:
        env.render()
        state = stack_frames(state_stack)

        # Choose an action
        action = agent.select_action(state)
        
        # Perform action
        next_state, reward, done, _, _ = env.step(action)
        
        # Process next state (frame) and add to the stack
        next_frame = preprocess_frame(env.render())
        state_stack.append(next_frame)
        next_state_stack = stack_frames(state_stack)

        # Store experience in replay memory
        agent.memory.add((state, action, reward, next_state_stack, done))
        
        # Train the agent with experience replay
        agent.replay()

        # Update the state
        state_stack = state_stack

        total_reward += reward
        
        # Periodically update target network
        if e % agent.update_frequency == 0:
            agent.update_target_network()

    print(f"Episode: {e+1}/{num_episodes}, Total Reward: {total_reward}")

env.close()
# Out:
# Episode: 1/2000, Total Reward: 2
# Episode: 2/2000, Total Reward: 0
# Episode: 3/2000, Total Reward: 0
# Episode: 4/2000, Total Reward: 38
# Episode: 5/2000, Total Reward: 0
# Episode: 6/2000, Total Reward: 0
# Episode: 7/2000, Total Reward: 0
# Episode: 8/2000, Total Reward: 0
# Episode: 9/2000, Total Reward: 0
# Episode: 10/2000, Total Reward: 36
# Episode: 11/2000, Total Reward: 0
# Episode: 12/2000, Total Reward: 0
# Episode: 13/2000, Total Reward: 0
# Episode: 14/2000, Total Reward: 0
# Episode: 15/2000, Total Reward: 0
# Episode: 16/2000, Total Reward: 0
# Episode: 17/2000, Total Reward: 0
# Episode: 18/2000, Total Reward: 10
# Episode: 19/2000, Total Reward: 0
# Episode: 20/2000, Total Reward: 0
# Episode: 21/2000, Total Reward: 0
# Episode: 22/2000, Total Reward: 0
# Episode: 23/2000, Total Reward: 0
# Episode: 24/2000, Total Reward: 82
# Episode: 25/2000, Total Reward: 0
# Episode: 26/2000, Total Reward: 0
# Episode: 27/2000, Total Reward: 0
# Episode: 28/2000, Total Reward: 0
# Episode: 29/2000, Total Reward: 0
# Episode: 30/2000, Total Reward: 0
# Episode: 31/2000, Total Reward: 130
# Episode: 32/2000, Total Reward: 0
# Episode: 33/2000, Total Reward: 0
# Episode: 34/2000, Total Reward: 0
# Episode: 35/2000, Total Reward: 32
# Episode: 36/2000, Total Reward: 0
# Episode: 37/2000, Total Reward: 6
# Episode: 38/2000, Total Reward: 0
# Episode: 39/2000, Total Reward: 0
# Episode: 40/2000, Total Reward: 48
# Episode: 41/2000, Total Reward: 0
# Episode: 42/2000, Total Reward: 0
# Episode: 43/2000, Total Reward: 0
# Episode: 44/2000, Total Reward: 0
# Episode: 45/2000, Total Reward: 6
# Episode: 46/2000, Total Reward: 0
# Episode: 47/2000, Total Reward: 0
# Episode: 48/2000, Total Reward: 0
# Episode: 49/2000, Total Reward: 0
# Episode: 50/2000, Total Reward: 0
# Episode: 51/2000, Total Reward: 0
# Episode: 52/2000, Total Reward: 10
# Episode: 53/2000, Total Reward: 0
# Episode: 54/2000, Total Reward: 0
# Episode: 55/2000, Total Reward: 6
# Episode: 56/2000, Total Reward: 0
# Episode: 57/2000, Total Reward: 42
# Episode: 58/2000, Total Reward: 0
# Episode: 59/2000, Total Reward: 0
# Episode: 60/2000, Total Reward: 0
# Episode: 61/2000, Total Reward: 0
# Episode: 62/2000, Total Reward: 0
# Episode: 63/2000, Total Reward: 0
# Episode: 64/2000, Total Reward: 0
# Episode: 65/2000, Total Reward: 0
# Episode: 66/2000, Total Reward: 18
# Episode: 67/2000, Total Reward: 0
# Episode: 68/2000, Total Reward: 0
# Episode: 69/2000, Total Reward: 0
# Episode: 70/2000, Total Reward: 0
# Episode: 71/2000, Total Reward: 0
# Episode: 72/2000, Total Reward: 50
# Episode: 73/2000, Total Reward: 0
# Episode: 74/2000, Total Reward: 38
# Episode: 75/2000, Total Reward: 0
# Episode: 76/2000, Total Reward: 0
# Episode: 77/2000, Total Reward: 0
# Episode: 78/2000, Total Reward: 26
# Episode: 79/2000, Total Reward: 0
# Episode: 80/2000, Total Reward: 0
# Episode: 81/2000, Total Reward: 0
# Episode: 82/2000, Total Reward: 0
# Episode: 83/2000, Total Reward: 0
# Episode: 84/2000, Total Reward: 0
# Episode: 85/2000, Total Reward: 18
# Episode: 86/2000, Total Reward: 0
# Episode: 87/2000, Total Reward: 6
# Episode: 88/2000, Total Reward: 0
# Episode: 89/2000, Total Reward: 0
# Episode: 90/2000, Total Reward: 0
# Episode: 91/2000, Total Reward: 0
# Episode: 92/2000, Total Reward: 0
# Episode: 93/2000, Total Reward: 50
# Episode: 94/2000, Total Reward: 0
# Episode: 95/2000, Total Reward: 0
# Episode: 96/2000, Total Reward: 0
# Episode: 97/2000, Total Reward: 0
# Episode: 98/2000, Total Reward: 0
# Episode: 99/2000, Total Reward: 6
# Episode: 100/2000, Total Reward: 0
# Episode: 101/2000, Total Reward: 0
# Episode: 102/2000, Total Reward: 66
# Episode: 103/2000, Total Reward: 0
# Episode: 104/2000, Total Reward: 0
# Episode: 105/2000, Total Reward: 0
# Episode: 106/2000, Total Reward: 0
# Episode: 107/2000, Total Reward: 0
# Episode: 108/2000, Total Reward: 0
# Episode: 109/2000, Total Reward: 0
# Episode: 110/2000, Total Reward: 0
# Episode: 111/2000, Total Reward: 0
# Episode: 112/2000, Total Reward: 10
# Episode: 113/2000, Total Reward: 0
# Episode: 114/2000, Total Reward: 0
# Episode: 115/2000, Total Reward: 0
# Episode: 116/2000, Total Reward: 46
# Episode: 117/2000, Total Reward: 0
# Episode: 118/2000, Total Reward: 94
# Episode: 119/2000, Total Reward: 0
# Episode: 120/2000, Total Reward: 0
# Episode: 121/2000, Total Reward: 0
# Episode: 122/2000, Total Reward: 68
# Episode: 123/2000, Total Reward: 0
# Episode: 124/2000, Total Reward: 0
# Episode: 125/2000, Total Reward: 40
# Episode: 126/2000, Total Reward: 0
# Episode: 127/2000, Total Reward: 6
# Episode: 128/2000, Total Reward: 0
# Episode: 129/2000, Total Reward: 4
# Episode: 130/2000, Total Reward: 0
# Episode: 131/2000, Total Reward: 14
# Episode: 132/2000, Total Reward: 0
# Episode: 133/2000, Total Reward: 42
# Episode: 134/2000, Total Reward: 0
# Episode: 135/2000, Total Reward: 0
# Episode: 136/2000, Total Reward: 0
# Episode: 137/2000, Total Reward: 0
# Episode: 138/2000, Total Reward: 128
# Episode: 139/2000, Total Reward: 0
# Episode: 140/2000, Total Reward: 14
# Episode: 141/2000, Total Reward: 0
# Episode: 142/2000, Total Reward: 0
# Episode: 143/2000, Total Reward: 0
# Episode: 144/2000, Total Reward: 22
# Episode: 145/2000, Total Reward: 0
# Episode: 146/2000, Total Reward: 0
# Episode: 147/2000, Total Reward: 0
# Episode: 148/2000, Total Reward: 0
# Episode: 149/2000, Total Reward: 26
# Episode: 150/2000, Total Reward: 0
# Episode: 151/2000, Total Reward: 66
# Episode: 152/2000, Total Reward: 0
# Episode: 153/2000, Total Reward: 0
# Episode: 154/2000, Total Reward: 0
# Episode: 155/2000, Total Reward: 86
# Episode: 156/2000, Total Reward: 0
# Episode: 157/2000, Total Reward: 0
# Episode: 158/2000, Total Reward: 34
# Episode: 159/2000, Total Reward: 0
# Episode: 160/2000, Total Reward: 0
# Episode: 161/2000, Total Reward: 0
# Episode: 162/2000, Total Reward: 0
# Episode: 163/2000, Total Reward: 0
# Episode: 164/2000, Total Reward: 0
# Episode: 165/2000, Total Reward: 0
# Episode: 166/2000, Total Reward: 96
# Episode: 167/2000, Total Reward: 0
# Episode: 168/2000, Total Reward: 0
# Episode: 169/2000, Total Reward: 34
# Episode: 170/2000, Total Reward: 0
# Episode: 171/2000, Total Reward: 0
# Episode: 172/2000, Total Reward: 170
# Episode: 173/2000, Total Reward: 0
# Episode: 174/2000, Total Reward: 0
# Episode: 175/2000, Total Reward: 0
# Episode: 176/2000, Total Reward: 74
# Episode: 177/2000, Total Reward: 0
# Episode: 178/2000, Total Reward: 0
# Episode: 179/2000, Total Reward: 0
# Episode: 180/2000, Total Reward: 54
# Episode: 181/2000, Total Reward: 0
# Episode: 182/2000, Total Reward: 30
# Episode: 183/2000, Total Reward: 0
# Episode: 184/2000, Total Reward: 0
# Episode: 185/2000, Total Reward: 0
# Episode: 186/2000, Total Reward: 0
# Episode: 187/2000, Total Reward: 0
# Episode: 188/2000, Total Reward: 0
# Episode: 189/2000, Total Reward: 0
# Episode: 190/2000, Total Reward: 0
# Episode: 191/2000, Total Reward: 0
# Episode: 192/2000, Total Reward: 0
# Episode: 193/2000, Total Reward: 0
# Episode: 194/2000, Total Reward: 0
# Episode: 195/2000, Total Reward: 0
# Episode: 196/2000, Total Reward: 0
# Episode: 197/2000, Total Reward: 28
# Episode: 198/2000, Total Reward: 0
# Episode: 199/2000, Total Reward: 0
# Episode: 200/2000, Total Reward: 0
# Episode: 201/2000, Total Reward: 0
# Episode: 202/2000, Total Reward: 6
# Episode: 203/2000, Total Reward: 0
# Episode: 204/2000, Total Reward: 0
# Episode: 205/2000, Total Reward: 0
# Episode: 206/2000, Total Reward: 0
# Episode: 207/2000, Total Reward: 0
# Episode: 208/2000, Total Reward: 0
# Episode: 209/2000, Total Reward: 0
# Episode: 210/2000, Total Reward: 0
# Episode: 211/2000, Total Reward: 0
# Episode: 212/2000, Total Reward: 0
# Episode: 213/2000, Total Reward: 0
# Episode: 214/2000, Total Reward: 0
# Episode: 215/2000, Total Reward: 38
# Episode: 216/2000, Total Reward: 0
# Episode: 217/2000, Total Reward: 0
# Episode: 218/2000, Total Reward: 22
# Episode: 219/2000, Total Reward: 0
# Episode: 220/2000, Total Reward: 0
# Episode: 221/2000, Total Reward: 0
# Episode: 222/2000, Total Reward: 0
# Episode: 223/2000, Total Reward: 0
# Episode: 224/2000, Total Reward: 0
# Episode: 225/2000, Total Reward: 14
# Episode: 226/2000, Total Reward: 0
# Episode: 227/2000, Total Reward: 0
# Episode: 228/2000, Total Reward: 0
# Episode: 229/2000, Total Reward: 20
# Episode: 230/2000, Total Reward: 0
# Episode: 231/2000, Total Reward: 0
# Episode: 232/2000, Total Reward: 14
# Episode: 233/2000, Total Reward: 0
# Episode: 234/2000, Total Reward: 0
# Episode: 235/2000, Total Reward: 0
# Episode: 236/2000, Total Reward: 0
# Episode: 237/2000, Total Reward: 0
# Episode: 238/2000, Total Reward: 0
# Episode: 239/2000, Total Reward: 50
# Episode: 240/2000, Total Reward: 0
# Episode: 241/2000, Total Reward: 0
# Episode: 242/2000, Total Reward: 0
# Episode: 243/2000, Total Reward: 0
# Episode: 244/2000, Total Reward: 0
# Episode: 245/2000, Total Reward: 0
# Episode: 246/2000, Total Reward: 58
# Episode: 247/2000, Total Reward: 0
# Episode: 248/2000, Total Reward: 242
# Episode: 249/2000, Total Reward: 0
# Episode: 250/2000, Total Reward: 0
# Episode: 251/2000, Total Reward: 0
# Episode: 252/2000, Total Reward: 0
# Episode: 253/2000, Total Reward: 130
# Episode: 254/2000, Total Reward: 0
# Episode: 255/2000, Total Reward: 0
# Episode: 256/2000, Total Reward: 0
# Episode: 257/2000, Total Reward: 0
# Episode: 258/2000, Total Reward: 0
# Episode: 259/2000, Total Reward: 26
# Episode: 260/2000, Total Reward: 0
# Episode: 261/2000, Total Reward: 0
# Episode: 262/2000, Total Reward: 0
# Episode: 263/2000, Total Reward: 0
# Episode: 264/2000, Total Reward: 0
# Episode: 265/2000, Total Reward: 0
# Episode: 266/2000, Total Reward: 0
# Episode: 267/2000, Total Reward: 0
# Episode: 268/2000, Total Reward: 6
# Episode: 269/2000, Total Reward: 0
# Episode: 270/2000, Total Reward: 26
# Episode: 271/2000, Total Reward: 0
# Episode: 272/2000, Total Reward: 0
# Episode: 273/2000, Total Reward: 50
# Episode: 274/2000, Total Reward: 0
# Episode: 275/2000, Total Reward: 0
# Episode: 276/2000, Total Reward: 18
# Episode: 277/2000, Total Reward: 0
# Episode: 278/2000, Total Reward: 0
# Episode: 279/2000, Total Reward: 26
# Episode: 280/2000, Total Reward: 0
# Episode: 281/2000, Total Reward: 0
# Episode: 282/2000, Total Reward: 0
# Episode: 283/2000, Total Reward: 14
# Episode: 284/2000, Total Reward: 0
# Episode: 285/2000, Total Reward: 0
# Episode: 286/2000, Total Reward: 10
# Episode: 287/2000, Total Reward: 0
# Episode: 288/2000, Total Reward: 0
# Episode: 289/2000, Total Reward: 0
# Episode: 290/2000, Total Reward: 0
# Episode: 291/2000, Total Reward: 88
# Episode: 292/2000, Total Reward: 0
# Episode: 293/2000, Total Reward: 0
# Episode: 294/2000, Total Reward: 0
# Episode: 295/2000, Total Reward: 0
# Episode: 296/2000, Total Reward: 4
# Episode: 297/2000, Total Reward: 0
# Episode: 298/2000, Total Reward: 0
# Episode: 299/2000, Total Reward: 0
# Episode: 300/2000, Total Reward: 0
# Episode: 301/2000, Total Reward: 114
# Episode: 302/2000, Total Reward: 0
# Episode: 303/2000, Total Reward: 0
# Episode: 304/2000, Total Reward: 0
# Episode: 305/2000, Total Reward: 0
# Episode: 306/2000, Total Reward: 0
# Episode: 307/2000, Total Reward: 0
# Episode: 308/2000, Total Reward: 0
# Episode: 309/2000, Total Reward: 0
# Episode: 310/2000, Total Reward: 62
# Episode: 311/2000, Total Reward: 0
# Episode: 312/2000, Total Reward: 0
# Episode: 313/2000, Total Reward: 0
# Episode: 314/2000, Total Reward: 0
# Episode: 315/2000, Total Reward: 66
# Episode: 316/2000, Total Reward: 0
# Episode: 317/2000, Total Reward: 122
# Episode: 318/2000, Total Reward: 0
# Episode: 319/2000, Total Reward: 0
# Episode: 320/2000, Total Reward: 0
# Episode: 321/2000, Total Reward: 0
# Episode: 322/2000, Total Reward: 0
# Episode: 323/2000, Total Reward: 0
# Episode: 324/2000, Total Reward: 0
# Episode: 325/2000, Total Reward: 0
# Episode: 326/2000, Total Reward: 0
# Episode: 327/2000, Total Reward: 0
# Episode: 328/2000, Total Reward: 0
# Episode: 329/2000, Total Reward: 0
# Episode: 330/2000, Total Reward: 0
# Episode: 331/2000, Total Reward: 0
# Episode: 332/2000, Total Reward: 0
# Episode: 333/2000, Total Reward: 0
# Episode: 334/2000, Total Reward: 0
# Episode: 335/2000, Total Reward: 0
# Episode: 336/2000, Total Reward: 0
# Episode: 337/2000, Total Reward: 0
# Episode: 338/2000, Total Reward: 0
# Episode: 339/2000, Total Reward: 0
# Episode: 340/2000, Total Reward: 0
# Episode: 341/2000, Total Reward: 0
# Episode: 342/2000, Total Reward: 150
# Episode: 343/2000, Total Reward: 0
# Episode: 344/2000, Total Reward: 0
# Episode: 345/2000, Total Reward: 0
# Episode: 346/2000, Total Reward: 0
# Episode: 347/2000, Total Reward: 82
# Episode: 348/2000, Total Reward: 0
# Episode: 349/2000, Total Reward: 50
# Episode: 350/2000, Total Reward: 0
# Episode: 351/2000, Total Reward: 18
# Episode: 352/2000, Total Reward: 0
# Episode: 353/2000, Total Reward: 0
# Episode: 354/2000, Total Reward: 0
# Episode: 355/2000, Total Reward: 22
# Episode: 356/2000, Total Reward: 0
# Episode: 357/2000, Total Reward: 0
# Episode: 358/2000, Total Reward: 0
# Episode: 359/2000, Total Reward: 0
# Episode: 360/2000, Total Reward: 0
# Episode: 361/2000, Total Reward: 6
# Episode: 362/2000, Total Reward: 0
# Episode: 363/2000, Total Reward: 22
# Episode: 364/2000, Total Reward: 0
# Episode: 365/2000, Total Reward: 0
# Episode: 366/2000, Total Reward: 34
# Episode: 367/2000, Total Reward: 0
# Episode: 368/2000, Total Reward: 0
# Episode: 369/2000, Total Reward: 78
# Episode: 370/2000, Total Reward: 0
# Episode: 371/2000, Total Reward: 34
# Episode: 372/2000, Total Reward: 0
# Episode: 373/2000, Total Reward: 70
# Episode: 374/2000, Total Reward: 0
# Episode: 375/2000, Total Reward: 0
# Episode: 376/2000, Total Reward: 0
# Episode: 377/2000, Total Reward: 6
# Episode: 378/2000, Total Reward: 0
# Episode: 379/2000, Total Reward: 0
# Episode: 380/2000, Total Reward: 18
# Episode: 381/2000, Total Reward: 0
# Episode: 382/2000, Total Reward: 74
# Episode: 383/2000, Total Reward: 0
# Episode: 384/2000, Total Reward: 0
# Episode: 385/2000, Total Reward: 0
# Episode: 386/2000, Total Reward: 0
# Episode: 387/2000, Total Reward: 0
# Episode: 388/2000, Total Reward: 0
# Episode: 389/2000, Total Reward: 0
# Episode: 390/2000, Total Reward: 0
# Episode: 391/2000, Total Reward: 0
# Episode: 392/2000, Total Reward: 0
# Episode: 393/2000, Total Reward: 0
# Episode: 394/2000, Total Reward: 0
# Episode: 395/2000, Total Reward: 0
# Episode: 396/2000, Total Reward: 102
# Episode: 397/2000, Total Reward: 0
# Episode: 398/2000, Total Reward: 0
# Episode: 399/2000, Total Reward: 0
# Episode: 400/2000, Total Reward: 98
# Episode: 401/2000, Total Reward: 0
# Episode: 402/2000, Total Reward: 0
# Episode: 403/2000, Total Reward: 0
# Episode: 404/2000, Total Reward: 0
# Episode: 405/2000, Total Reward: 0
# Episode: 406/2000, Total Reward: 0
# Episode: 407/2000, Total Reward: 0
# Episode: 408/2000, Total Reward: 0
# Episode: 409/2000, Total Reward: 0
# Episode: 410/2000, Total Reward: 30
# Episode: 411/2000, Total Reward: 0
# Episode: 412/2000, Total Reward: 30
# Episode: 413/2000, Total Reward: 0
# Episode: 414/2000, Total Reward: 30
# Episode: 415/2000, Total Reward: 0
# Episode: 416/2000, Total Reward: 54
# Episode: 417/2000, Total Reward: 0
# Episode: 418/2000, Total Reward: 0
# Episode: 419/2000, Total Reward: 0
# Episode: 420/2000, Total Reward: 0
# Episode: 421/2000, Total Reward: 0
# Episode: 422/2000, Total Reward: 0
# Episode: 423/2000, Total Reward: 0
# Episode: 424/2000, Total Reward: 0
# Episode: 425/2000, Total Reward: 0
# Episode: 426/2000, Total Reward: 0
# Episode: 427/2000, Total Reward: 0
# Episode: 428/2000, Total Reward: 14
# Episode: 429/2000, Total Reward: 0
# Episode: 430/2000, Total Reward: 0
# Episode: 431/2000, Total Reward: 0
# Episode: 432/2000, Total Reward: 0
# Episode: 433/2000, Total Reward: 0
# Episode: 434/2000, Total Reward: 0
# Episode: 435/2000, Total Reward: 0
# Episode: 436/2000, Total Reward: 0
# Episode: 437/2000, Total Reward: 0
# Episode: 438/2000, Total Reward: 0
# Episode: 439/2000, Total Reward: 0
# Episode: 440/2000, Total Reward: 0
# Episode: 441/2000, Total Reward: 34
# Episode: 442/2000, Total Reward: 0
# Episode: 443/2000, Total Reward: 0
# Episode: 444/2000, Total Reward: 0
# Episode: 445/2000, Total Reward: 0
# Episode: 446/2000, Total Reward: 0
# Episode: 447/2000, Total Reward: 0
# Episode: 448/2000, Total Reward: 18
# Episode: 449/2000, Total Reward: 0
# Episode: 450/2000, Total Reward: 0
# Episode: 451/2000, Total Reward: 0
# Episode: 452/2000, Total Reward: 22
# Episode: 453/2000, Total Reward: 0
# Episode: 454/2000, Total Reward: 0
# Episode: 455/2000, Total Reward: 0
# Episode: 456/2000, Total Reward: 0
# Episode: 457/2000, Total Reward: 6
# Episode: 458/2000, Total Reward: 0
# Episode: 459/2000, Total Reward: 44
# Episode: 460/2000, Total Reward: 0
# Episode: 461/2000, Total Reward: 0
# Episode: 462/2000, Total Reward: 0
# Episode: 463/2000, Total Reward: 0
# Episode: 464/2000, Total Reward: 10
# Episode: 465/2000, Total Reward: 0
# Episode: 466/2000, Total Reward: 0
# Episode: 467/2000, Total Reward: 0
# Episode: 468/2000, Total Reward: 134
# Episode: 469/2000, Total Reward: 0
# Episode: 470/2000, Total Reward: 0
# Episode: 471/2000, Total Reward: 0
# Episode: 472/2000, Total Reward: 0
# Episode: 473/2000, Total Reward: 0
# Episode: 474/2000, Total Reward: 0
# Episode: 475/2000, Total Reward: 110
# Episode: 476/2000, Total Reward: 0
# Episode: 477/2000, Total Reward: 36
# Episode: 478/2000, Total Reward: 0
# Episode: 479/2000, Total Reward: 0
# Episode: 480/2000, Total Reward: 0
# Episode: 481/2000, Total Reward: 10
# Episode: 482/2000, Total Reward: 0
# Episode: 483/2000, Total Reward: 0
# Episode: 484/2000, Total Reward: 0
# Episode: 485/2000, Total Reward: 66
# Episode: 486/2000, Total Reward: 0
# Episode: 487/2000, Total Reward: 0
# Episode: 488/2000, Total Reward: 0
# Episode: 489/2000, Total Reward: 0
# Episode: 490/2000, Total Reward: 22
# Episode: 491/2000, Total Reward: 0
# Episode: 492/2000, Total Reward: 8
# Episode: 493/2000, Total Reward: 0
# Episode: 494/2000, Total Reward: 0
# Episode: 495/2000, Total Reward: 0
# Episode: 496/2000, Total Reward: 0
# Episode: 497/2000, Total Reward: 10
# Episode: 498/2000, Total Reward: 0
# Episode: 499/2000, Total Reward: 102
# Episode: 500/2000, Total Reward: 0
# Episode: 501/2000, Total Reward: 6
# Episode: 502/2000, Total Reward: 0
# Episode: 503/2000, Total Reward: 0
# Episode: 504/2000, Total Reward: 34
# Episode: 505/2000, Total Reward: 0
# Episode: 506/2000, Total Reward: 70
# Episode: 507/2000, Total Reward: 0
# Episode: 508/2000, Total Reward: 10
# Episode: 509/2000, Total Reward: 0
# Episode: 510/2000, Total Reward: 0
# Episode: 511/2000, Total Reward: 54
# Episode: 512/2000, Total Reward: 0
# Episode: 513/2000, Total Reward: 0
# Episode: 514/2000, Total Reward: 0
# Episode: 515/2000, Total Reward: 0
# Episode: 516/2000, Total Reward: 0
# Episode: 517/2000, Total Reward: 0
# Episode: 518/2000, Total Reward: 0
# Episode: 519/2000, Total Reward: 0
# Episode: 520/2000, Total Reward: 0
# Episode: 521/2000, Total Reward: 0
# Episode: 522/2000, Total Reward: 0
# Episode: 523/2000, Total Reward: 30
# Episode: 524/2000, Total Reward: 0
# Episode: 525/2000, Total Reward: 0
# Episode: 526/2000, Total Reward: 26
# Episode: 527/2000, Total Reward: 0
# Episode: 528/2000, Total Reward: 0
# Episode: 529/2000, Total Reward: 0
# Episode: 530/2000, Total Reward: 0
# Episode: 531/2000, Total Reward: 10
# Episode: 532/2000, Total Reward: 0
# Episode: 533/2000, Total Reward: 0
# Episode: 534/2000, Total Reward: 0
# Episode: 535/2000, Total Reward: 0
# Episode: 536/2000, Total Reward: 0
# Episode: 537/2000, Total Reward: 86
# Episode: 538/2000, Total Reward: 0
# Episode: 539/2000, Total Reward: 0
# Episode: 540/2000, Total Reward: 0
# Episode: 541/2000, Total Reward: 0
# Episode: 542/2000, Total Reward: 226
# Episode: 543/2000, Total Reward: 0
# Episode: 544/2000, Total Reward: 128
# Episode: 545/2000, Total Reward: 0
# Episode: 546/2000, Total Reward: 0
# Episode: 547/2000, Total Reward: 0
# Episode: 548/2000, Total Reward: 0
# Episode: 549/2000, Total Reward: 0
# Episode: 550/2000, Total Reward: 0
# Episode: 551/2000, Total Reward: 0
# Episode: 552/2000, Total Reward: 0
# Episode: 553/2000, Total Reward: 0
# Episode: 554/2000, Total Reward: 0
# Episode: 555/2000, Total Reward: 0
# Episode: 556/2000, Total Reward: 38
# Episode: 557/2000, Total Reward: 0
# Episode: 558/2000, Total Reward: 0
# Episode: 559/2000, Total Reward: 0
# Episode: 560/2000, Total Reward: 0
# Episode: 561/2000, Total Reward: 0
# Episode: 562/2000, Total Reward: 10
# Episode: 563/2000, Total Reward: 0
# Episode: 564/2000, Total Reward: 10
# Episode: 565/2000, Total Reward: 0
# Episode: 566/2000, Total Reward: 0
# Episode: 567/2000, Total Reward: 0
# Episode: 568/2000, Total Reward: 0
# Episode: 569/2000, Total Reward: 42
# Episode: 570/2000, Total Reward: 0
# Episode: 571/2000, Total Reward: 0
# Episode: 572/2000, Total Reward: 0
# Episode: 573/2000, Total Reward: 0
# Episode: 574/2000, Total Reward: 0
# Episode: 575/2000, Total Reward: 0
# Episode: 576/2000, Total Reward: 0
# Episode: 577/2000, Total Reward: 0
# Episode: 578/2000, Total Reward: 0
# Episode: 579/2000, Total Reward: 0
# Episode: 580/2000, Total Reward: 74
# Episode: 581/2000, Total Reward: 0
# Episode: 582/2000, Total Reward: 0
# Episode: 583/2000, Total Reward: 0
# Episode: 584/2000, Total Reward: 30
# Episode: 585/2000, Total Reward: 0
# Episode: 586/2000, Total Reward: 34
# Episode: 587/2000, Total Reward: 0
# Episode: 588/2000, Total Reward: 0
# Episode: 589/2000, Total Reward: 0
# Episode: 590/2000, Total Reward: 0
# Episode: 591/2000, Total Reward: 0
# Episode: 592/2000, Total Reward: 0
# Episode: 593/2000, Total Reward: 0
# Episode: 594/2000, Total Reward: 0
# Episode: 595/2000, Total Reward: 0
# Episode: 596/2000, Total Reward: 0
# Episode: 597/2000, Total Reward: 0
# Episode: 598/2000, Total Reward: 0
# Episode: 599/2000, Total Reward: 0
# Episode: 600/2000, Total Reward: 38
# Episode: 601/2000, Total Reward: 0
# Episode: 602/2000, Total Reward: 0
# Episode: 603/2000, Total Reward: 0
# Episode: 604/2000, Total Reward: 0
# Episode: 605/2000, Total Reward: 0
# Episode: 606/2000, Total Reward: 34
# Episode: 607/2000, Total Reward: 0
# Episode: 608/2000, Total Reward: 0
# Episode: 609/2000, Total Reward: 42
# Episode: 610/2000, Total Reward: 0
# Episode: 611/2000, Total Reward: 0
# Episode: 612/2000, Total Reward: 0
# Episode: 613/2000, Total Reward: 38
# Episode: 614/2000, Total Reward: 0
# Episode: 615/2000, Total Reward: 0
# Episode: 616/2000, Total Reward: 0
# Episode: 617/2000, Total Reward: 20
# Episode: 618/2000, Total Reward: 0
# Episode: 619/2000, Total Reward: 0
# Episode: 620/2000, Total Reward: 0
# Episode: 621/2000, Total Reward: 0
# Episode: 622/2000, Total Reward: 0
# Episode: 623/2000, Total Reward: 0
# Episode: 624/2000, Total Reward: 0
# Episode: 625/2000, Total Reward: 0
# Episode: 626/2000, Total Reward: 0
# Episode: 627/2000, Total Reward: 26
# Episode: 628/2000, Total Reward: 0
# Episode: 629/2000, Total Reward: 0
# Episode: 630/2000, Total Reward: 0
# Episode: 631/2000, Total Reward: 0
# Episode: 632/2000, Total Reward: 0
# Episode: 633/2000, Total Reward: 6
# Episode: 634/2000, Total Reward: 0
# Episode: 635/2000, Total Reward: 46
# Episode: 636/2000, Total Reward: 0
# Episode: 637/2000, Total Reward: 0
# Episode: 638/2000, Total Reward: 0
# Episode: 639/2000, Total Reward: 22
# Episode: 640/2000, Total Reward: 0
# Episode: 641/2000, Total Reward: 22
# Episode: 642/2000, Total Reward: 0
# Episode: 643/2000, Total Reward: 30
# Episode: 644/2000, Total Reward: 0
# Episode: 645/2000, Total Reward: 42
# Episode: 646/2000, Total Reward: 0
# Episode: 647/2000, Total Reward: 0
# Episode: 648/2000, Total Reward: 0
# Episode: 649/2000, Total Reward: 0
# Episode: 650/2000, Total Reward: 0
# Episode: 651/2000, Total Reward: 0
# Episode: 652/2000, Total Reward: 0
# Episode: 653/2000, Total Reward: 46
# Episode: 654/2000, Total Reward: 0
# Episode: 655/2000, Total Reward: 0
# Episode: 656/2000, Total Reward: 0
# Episode: 657/2000, Total Reward: 0
# Episode: 658/2000, Total Reward: 0
# Episode: 659/2000, Total Reward: 94
# Episode: 660/2000, Total Reward: 0
# Episode: 661/2000, Total Reward: 30
# Episode: 662/2000, Total Reward: 0
# Episode: 663/2000, Total Reward: 0
# Episode: 664/2000, Total Reward: 0
# Episode: 665/2000, Total Reward: 0
# Episode: 666/2000, Total Reward: 0
# Episode: 667/2000, Total Reward: 0
# Episode: 668/2000, Total Reward: 0
# Episode: 669/2000, Total Reward: 0
# Episode: 670/2000, Total Reward: 0
# Episode: 671/2000, Total Reward: 0
# Episode: 672/2000, Total Reward: 0
# Episode: 673/2000, Total Reward: 0
# Episode: 674/2000, Total Reward: 0
# Episode: 675/2000, Total Reward: 0
# Episode: 676/2000, Total Reward: 22
# Episode: 677/2000, Total Reward: 0
# Episode: 678/2000, Total Reward: 0
# Episode: 679/2000, Total Reward: 0
# Episode: 680/2000, Total Reward: 10
# Episode: 681/2000, Total Reward: 0
# Episode: 682/2000, Total Reward: 0
# Episode: 683/2000, Total Reward: 0
# Episode: 684/2000, Total Reward: 0
# Episode: 685/2000, Total Reward: 0
# Episode: 686/2000, Total Reward: 0
# Episode: 687/2000, Total Reward: 0
# Episode: 688/2000, Total Reward: 0
# Episode: 689/2000, Total Reward: 90
# Episode: 690/2000, Total Reward: 0
# Episode: 691/2000, Total Reward: 0
# Episode: 692/2000, Total Reward: 0
# Episode: 693/2000, Total Reward: 0
# Episode: 694/2000, Total Reward: 0
# Episode: 695/2000, Total Reward: 0
# Episode: 696/2000, Total Reward: 0
# Episode: 697/2000, Total Reward: 0
# Episode: 698/2000, Total Reward: 0
# Episode: 699/2000, Total Reward: 0
# Episode: 700/2000, Total Reward: 0
# Episode: 701/2000, Total Reward: 0
# Episode: 702/2000, Total Reward: 0
# Episode: 703/2000, Total Reward: 0
# Episode: 704/2000, Total Reward: 0
# Episode: 705/2000, Total Reward: 0
# Episode: 706/2000, Total Reward: 0
# Episode: 707/2000, Total Reward: 102
# Episode: 708/2000, Total Reward: 0
# Episode: 709/2000, Total Reward: 0
# Episode: 710/2000, Total Reward: 0
# Episode: 711/2000, Total Reward: 54
# Episode: 712/2000, Total Reward: 0
# Episode: 713/2000, Total Reward: 0
# Episode: 714/2000, Total Reward: 0
# Episode: 715/2000, Total Reward: 34
# Episode: 716/2000, Total Reward: 0
# Episode: 717/2000, Total Reward: 0
# Episode: 718/2000, Total Reward: 6
# Episode: 719/2000, Total Reward: 0
# Episode: 720/2000, Total Reward: 0
# Episode: 721/2000, Total Reward: 2
# Episode: 722/2000, Total Reward: 0
# Episode: 723/2000, Total Reward: 0
# Episode: 724/2000, Total Reward: 0
# Episode: 725/2000, Total Reward: 0
# Episode: 726/2000, Total Reward: 0
# Episode: 727/2000, Total Reward: 0
# Episode: 728/2000, Total Reward: 0
# Episode: 729/2000, Total Reward: 0
# Episode: 730/2000, Total Reward: 0
# Episode: 731/2000, Total Reward: 0
# Episode: 732/2000, Total Reward: 0
# Episode: 733/2000, Total Reward: 0
# Episode: 734/2000, Total Reward: 0
# Episode: 735/2000, Total Reward: 0
# Episode: 736/2000, Total Reward: 0
# Episode: 737/2000, Total Reward: 0
# Episode: 738/2000, Total Reward: 0
# Episode: 739/2000, Total Reward: 6
# Episode: 740/2000, Total Reward: 0
# Episode: 741/2000, Total Reward: 34
# Episode: 742/2000, Total Reward: 0
# Episode: 743/2000, Total Reward: 46
# Episode: 744/2000, Total Reward: 0
# Episode: 745/2000, Total Reward: 0
# Episode: 746/2000, Total Reward: 0
# Episode: 747/2000, Total Reward: 0
# Episode: 748/2000, Total Reward: 0
# Episode: 749/2000, Total Reward: 0
# Episode: 750/2000, Total Reward: 0
# Episode: 751/2000, Total Reward: 0
# Episode: 752/2000, Total Reward: 126
# Episode: 753/2000, Total Reward: 0
# Episode: 754/2000, Total Reward: 20
# Episode: 755/2000, Total Reward: 0
# Episode: 756/2000, Total Reward: 0
# Episode: 757/2000, Total Reward: 0
# Episode: 758/2000, Total Reward: 0
# Episode: 759/2000, Total Reward: 0
# Episode: 760/2000, Total Reward: 22
# Episode: 761/2000, Total Reward: 0
# Episode: 762/2000, Total Reward: 0
# Episode: 763/2000, Total Reward: 0
# Episode: 764/2000, Total Reward: 18
# Episode: 765/2000, Total Reward: 0
# Episode: 766/2000, Total Reward: 0
# Episode: 767/2000, Total Reward: 0
# Episode: 768/2000, Total Reward: 74
# Episode: 769/2000, Total Reward: 0
# Episode: 770/2000, Total Reward: 0
# Episode: 771/2000, Total Reward: 0
# Episode: 772/2000, Total Reward: 0
# Episode: 773/2000, Total Reward: 0
# Episode: 774/2000, Total Reward: 10
# Episode: 775/2000, Total Reward: 0
# Episode: 776/2000, Total Reward: 0
# Episode: 777/2000, Total Reward: 0
# Episode: 778/2000, Total Reward: 0
# Episode: 779/2000, Total Reward: 0
# Episode: 780/2000, Total Reward: 0
# Episode: 781/2000, Total Reward: 0
# Episode: 782/2000, Total Reward: 0
# Episode: 783/2000, Total Reward: 0
# Episode: 784/2000, Total Reward: 0
# Episode: 785/2000, Total Reward: 0
# Episode: 786/2000, Total Reward: 0
# Episode: 787/2000, Total Reward: 0
# Episode: 788/2000, Total Reward: 0
# Episode: 789/2000, Total Reward: 0
# Episode: 790/2000, Total Reward: 0
# Episode: 791/2000, Total Reward: 0
# Episode: 792/2000, Total Reward: 90
# Episode: 793/2000, Total Reward: 0
# Episode: 794/2000, Total Reward: 0
# Episode: 795/2000, Total Reward: 0
# Episode: 796/2000, Total Reward: 0
# Episode: 797/2000, Total Reward: 0
# Episode: 798/2000, Total Reward: 0
# Episode: 799/2000, Total Reward: 0
# Episode: 800/2000, Total Reward: 66
# Episode: 801/2000, Total Reward: 0
# Episode: 802/2000, Total Reward: 0
# Episode: 803/2000, Total Reward: 0
# Episode: 804/2000, Total Reward: 0
# Episode: 805/2000, Total Reward: 0
# Episode: 806/2000, Total Reward: 0
# Episode: 807/2000, Total Reward: 0
# Episode: 808/2000, Total Reward: 0
# Episode: 809/2000, Total Reward: 0
# Episode: 810/2000, Total Reward: 6
# Episode: 811/2000, Total Reward: 0
# Episode: 812/2000, Total Reward: 0
# Episode: 813/2000, Total Reward: 60
# Episode: 814/2000, Total Reward: 0
# Episode: 815/2000, Total Reward: 0
# Episode: 816/2000, Total Reward: 10
# Episode: 817/2000, Total Reward: 0
# Episode: 818/2000, Total Reward: 110
# Episode: 819/2000, Total Reward: 0
# Episode: 820/2000, Total Reward: 14
# Episode: 821/2000, Total Reward: 0
# Episode: 822/2000, Total Reward: 74
# Episode: 823/2000, Total Reward: 0
# Episode: 824/2000, Total Reward: 0
# Episode: 825/2000, Total Reward: 0
# Episode: 826/2000, Total Reward: 0
# Episode: 827/2000, Total Reward: 0
# Episode: 828/2000, Total Reward: 0
# Episode: 829/2000, Total Reward: 0
# Episode: 830/2000, Total Reward: 0
# Episode: 831/2000, Total Reward: 14
# Episode: 832/2000, Total Reward: 0
# Episode: 833/2000, Total Reward: 0
# Episode: 834/2000, Total Reward: 0
# Episode: 835/2000, Total Reward: 18
# Episode: 836/2000, Total Reward: 0
# Episode: 837/2000, Total Reward: 0
# Episode: 838/2000, Total Reward: 54
# Episode: 839/2000, Total Reward: 0
# Episode: 840/2000, Total Reward: 54
# Episode: 841/2000, Total Reward: 0
# Episode: 842/2000, Total Reward: 0
# Episode: 843/2000, Total Reward: 0
# Episode: 844/2000, Total Reward: 0
# Episode: 845/2000, Total Reward: 22
# Episode: 846/2000, Total Reward: 0
# Episode: 847/2000, Total Reward: 42
# Episode: 848/2000, Total Reward: 0
# Episode: 849/2000, Total Reward: 10
# Episode: 850/2000, Total Reward: 0
# Episode: 851/2000, Total Reward: 0
# Episode: 852/2000, Total Reward: 0
# Episode: 853/2000, Total Reward: 0
# Episode: 854/2000, Total Reward: 0
# Episode: 855/2000, Total Reward: 0
# Episode: 856/2000, Total Reward: 34
# Episode: 857/2000, Total Reward: 0
# Episode: 858/2000, Total Reward: 0
# Episode: 859/2000, Total Reward: 6
# Episode: 860/2000, Total Reward: 0
# Episode: 861/2000, Total Reward: 32
# Episode: 862/2000, Total Reward: 0
# Episode: 863/2000, Total Reward: 0
# Episode: 864/2000, Total Reward: 0
# Episode: 865/2000, Total Reward: 0
# Episode: 866/2000, Total Reward: 0
# Episode: 867/2000, Total Reward: 0
# Episode: 868/2000, Total Reward: 0
# Episode: 869/2000, Total Reward: 0
# Episode: 870/2000, Total Reward: 0
# Episode: 871/2000, Total Reward: 0
# Episode: 872/2000, Total Reward: 0
# Episode: 873/2000, Total Reward: 0
# Episode: 874/2000, Total Reward: 0
# Episode: 875/2000, Total Reward: 0
# Episode: 876/2000, Total Reward: 40
# Episode: 877/2000, Total Reward: 0
# Episode: 878/2000, Total Reward: 42
# Episode: 879/2000, Total Reward: 0
# Episode: 880/2000, Total Reward: 0
# Episode: 881/2000, Total Reward: 0
# Episode: 882/2000, Total Reward: 0
# Episode: 883/2000, Total Reward: 0
# Episode: 884/2000, Total Reward: 0
# Episode: 885/2000, Total Reward: 0
# Episode: 886/2000, Total Reward: 18
# Episode: 887/2000, Total Reward: 0
# Episode: 888/2000, Total Reward: 18
# Episode: 889/2000, Total Reward: 0
# Episode: 890/2000, Total Reward: 0
# Episode: 891/2000, Total Reward: 0
# Episode: 892/2000, Total Reward: 14
# Episode: 893/2000, Total Reward: 0
# Episode: 894/2000, Total Reward: 0
# Episode: 895/2000, Total Reward: 0
# Episode: 896/2000, Total Reward: 0
# Episode: 897/2000, Total Reward: 0
# Episode: 898/2000, Total Reward: 0
# Episode: 899/2000, Total Reward: 0
# Episode: 900/2000, Total Reward: 0
# Episode: 901/2000, Total Reward: 0
# Episode: 902/2000, Total Reward: 0
# Episode: 903/2000, Total Reward: 0
# Episode: 904/2000, Total Reward: 0
# Episode: 905/2000, Total Reward: 0
# Episode: 906/2000, Total Reward: 0
# Episode: 907/2000, Total Reward: 0
# Episode: 908/2000, Total Reward: 0
# Episode: 909/2000, Total Reward: 0
# Episode: 910/2000, Total Reward: 0
# Episode: 911/2000, Total Reward: 0
# Episode: 912/2000, Total Reward: 0
# Episode: 913/2000, Total Reward: 0
# Episode: 914/2000, Total Reward: 0
# Episode: 915/2000, Total Reward: 0
# Episode: 916/2000, Total Reward: 0
# Episode: 917/2000, Total Reward: 0
# Episode: 918/2000, Total Reward: 28
# Episode: 919/2000, Total Reward: 0
# Episode: 920/2000, Total Reward: 18
# Episode: 921/2000, Total Reward: 0
# Episode: 922/2000, Total Reward: 72
# Episode: 923/2000, Total Reward: 0
# Episode: 924/2000, Total Reward: 0
# Episode: 925/2000, Total Reward: 0
# Episode: 926/2000, Total Reward: 0
# Episode: 927/2000, Total Reward: 0
# Episode: 928/2000, Total Reward: 0
# Episode: 929/2000, Total Reward: 0
# Episode: 930/2000, Total Reward: 0
# Episode: 931/2000, Total Reward: 0
# Episode: 932/2000, Total Reward: 0
# Episode: 933/2000, Total Reward: 0
# Episode: 934/2000, Total Reward: 0
# Episode: 935/2000, Total Reward: 110
# Episode: 936/2000, Total Reward: 0
# Episode: 937/2000, Total Reward: 0
# Episode: 938/2000, Total Reward: 0
# Episode: 939/2000, Total Reward: 0
# Episode: 940/2000, Total Reward: 0
# Episode: 941/2000, Total Reward: 16
# Episode: 942/2000, Total Reward: 0
# Episode: 943/2000, Total Reward: 30
# Episode: 944/2000, Total Reward: 0
# Episode: 945/2000, Total Reward: 0
# Episode: 946/2000, Total Reward: 0
# Episode: 947/2000, Total Reward: 0
# Episode: 948/2000, Total Reward: 0
# Episode: 949/2000, Total Reward: 0
# Episode: 950/2000, Total Reward: 0
# Episode: 951/2000, Total Reward: 78
# Episode: 952/2000, Total Reward: 0
# Episode: 953/2000, Total Reward: 0
# Episode: 954/2000, Total Reward: 0
# Episode: 955/2000, Total Reward: 52
# Episode: 956/2000, Total Reward: 0
# Episode: 957/2000, Total Reward: 14
# Episode: 958/2000, Total Reward: 0
# Episode: 959/2000, Total Reward: 0
# Episode: 960/2000, Total Reward: 50
# Episode: 961/2000, Total Reward: 0
# Episode: 962/2000, Total Reward: 0
# Episode: 963/2000, Total Reward: 50
# Episode: 964/2000, Total Reward: 0
# Episode: 965/2000, Total Reward: 0
# Episode: 966/2000, Total Reward: 0
# Episode: 967/2000, Total Reward: 0
# Episode: 968/2000, Total Reward: 0
# Episode: 969/2000, Total Reward: 0
# Episode: 970/2000, Total Reward: 0
# Episode: 971/2000, Total Reward: 0
# Episode: 972/2000, Total Reward: 0
# Episode: 973/2000, Total Reward: 0
# Episode: 974/2000, Total Reward: 0
# Episode: 975/2000, Total Reward: 0
# Episode: 976/2000, Total Reward: 0
# Episode: 977/2000, Total Reward: 0
# Episode: 978/2000, Total Reward: 6
# Episode: 979/2000, Total Reward: 0
# Episode: 980/2000, Total Reward: 34
# Episode: 981/2000, Total Reward: 0
# Episode: 982/2000, Total Reward: 0
# Episode: 983/2000, Total Reward: 38
# Episode: 984/2000, Total Reward: 0
# Episode: 985/2000, Total Reward: 0
# Episode: 986/2000, Total Reward: 0
# Episode: 987/2000, Total Reward: 0
# Episode: 988/2000, Total Reward: 0
# Episode: 989/2000, Total Reward: 30
# Episode: 990/2000, Total Reward: 0
# Episode: 991/2000, Total Reward: 94
# Episode: 992/2000, Total Reward: 0
# Episode: 993/2000, Total Reward: 0
# Episode: 994/2000, Total Reward: 0
# Episode: 995/2000, Total Reward: 0
# Episode: 996/2000, Total Reward: 0
# Episode: 997/2000, Total Reward: 0
# Episode: 998/2000, Total Reward: 10
# Episode: 999/2000, Total Reward: 0
# Episode: 1000/2000, Total Reward: 72
# Episode: 1001/2000, Total Reward: 0
# Episode: 1002/2000, Total Reward: 0
# Episode: 1003/2000, Total Reward: 0
# Episode: 1004/2000, Total Reward: 0
# Episode: 1005/2000, Total Reward: 12
# Episode: 1006/2000, Total Reward: 0
# Episode: 1007/2000, Total Reward: 58
# Episode: 1008/2000, Total Reward: 0
# Episode: 1009/2000, Total Reward: 0
# Episode: 1010/2000, Total Reward: 0
# Episode: 1011/2000, Total Reward: 30
# Episode: 1012/2000, Total Reward: 0
# Episode: 1013/2000, Total Reward: 0
# Episode: 1014/2000, Total Reward: 46
# Episode: 1015/2000, Total Reward: 0
# Episode: 1016/2000, Total Reward: 14
# Episode: 1017/2000, Total Reward: 0
# Episode: 1018/2000, Total Reward: 4
# Episode: 1019/2000, Total Reward: 0
# Episode: 1020/2000, Total Reward: 46
# Episode: 1021/2000, Total Reward: 0
# Episode: 1022/2000, Total Reward: 0
# Episode: 1023/2000, Total Reward: 30
# Episode: 1024/2000, Total Reward: 0
# Episode: 1025/2000, Total Reward: 0
# Episode: 1026/2000, Total Reward: 0
# Episode: 1027/2000, Total Reward: 0
# Episode: 1028/2000, Total Reward: 58
# Episode: 1029/2000, Total Reward: 0
# Episode: 1030/2000, Total Reward: 0
# Episode: 1031/2000, Total Reward: 0
# Episode: 1032/2000, Total Reward: 0
# Episode: 1033/2000, Total Reward: 0
# Episode: 1034/2000, Total Reward: 0
# Episode: 1035/2000, Total Reward: 0
# Episode: 1036/2000, Total Reward: 0
# Episode: 1037/2000, Total Reward: 114
# Episode: 1038/2000, Total Reward: 0
# Episode: 1039/2000, Total Reward: 0
# Episode: 1040/2000, Total Reward: 0
# Episode: 1041/2000, Total Reward: 0
# Episode: 1042/2000, Total Reward: 0
# Episode: 1043/2000, Total Reward: 0
# Episode: 1044/2000, Total Reward: 0
# Episode: 1045/2000, Total Reward: 0
# Episode: 1046/2000, Total Reward: 0
# Episode: 1047/2000, Total Reward: 10
# Episode: 1048/2000, Total Reward: 0
# Episode: 1049/2000, Total Reward: 0
# Episode: 1050/2000, Total Reward: 0
# Episode: 1051/2000, Total Reward: 0
# Episode: 1052/2000, Total Reward: 0
# Episode: 1053/2000, Total Reward: 0
# Episode: 1054/2000, Total Reward: 0
# Episode: 1055/2000, Total Reward: 0
# Episode: 1056/2000, Total Reward: 0
# Episode: 1057/2000, Total Reward: 0
# Episode: 1058/2000, Total Reward: 0
# Episode: 1059/2000, Total Reward: 0
# Episode: 1060/2000, Total Reward: 0
# Episode: 1061/2000, Total Reward: 22
# Episode: 1062/2000, Total Reward: 0
# Episode: 1063/2000, Total Reward: 0
# Episode: 1064/2000, Total Reward: 0
# Episode: 1065/2000, Total Reward: 0
# Episode: 1066/2000, Total Reward: 0
# Episode: 1067/2000, Total Reward: 0
# Episode: 1068/2000, Total Reward: 0
# Episode: 1069/2000, Total Reward: 0
# Episode: 1070/2000, Total Reward: 0
# Episode: 1071/2000, Total Reward: 0
# Episode: 1072/2000, Total Reward: 0
# Episode: 1073/2000, Total Reward: 0
# Episode: 1074/2000, Total Reward: 0
# Episode: 1075/2000, Total Reward: 18
# Episode: 1076/2000, Total Reward: 0
# Episode: 1077/2000, Total Reward: 18
# Episode: 1078/2000, Total Reward: 0
# Episode: 1079/2000, Total Reward: 38
# Episode: 1080/2000, Total Reward: 0
# Episode: 1081/2000, Total Reward: 0
# Episode: 1082/2000, Total Reward: 0
# Episode: 1083/2000, Total Reward: 0
# Episode: 1084/2000, Total Reward: 0
# Episode: 1085/2000, Total Reward: 0
# Episode: 1086/2000, Total Reward: 0
# Episode: 1087/2000, Total Reward: 0
# Episode: 1088/2000, Total Reward: 34
# Episode: 1089/2000, Total Reward: 0
# Episode: 1090/2000, Total Reward: 0
# Episode: 1091/2000, Total Reward: 56
# Episode: 1092/2000, Total Reward: 0
# Episode: 1093/2000, Total Reward: 0
# Episode: 1094/2000, Total Reward: 0
# Episode: 1095/2000, Total Reward: 0
# Episode: 1096/2000, Total Reward: 48
# Episode: 1097/2000, Total Reward: 0
# Episode: 1098/2000, Total Reward: 0
# Episode: 1099/2000, Total Reward: 34
# Episode: 1100/2000, Total Reward: 0
# Episode: 1101/2000, Total Reward: 0
# Episode: 1102/2000, Total Reward: 0
# Episode: 1103/2000, Total Reward: 0
# Episode: 1104/2000, Total Reward: 0
# Episode: 1105/2000, Total Reward: 0
# Episode: 1106/2000, Total Reward: 0
# Episode: 1107/2000, Total Reward: 26
# Episode: 1108/2000, Total Reward: 0
# Episode: 1109/2000, Total Reward: 0
# Episode: 1110/2000, Total Reward: 0
# Episode: 1111/2000, Total Reward: 0
# Episode: 1112/2000, Total Reward: 82
# Episode: 1113/2000, Total Reward: 0
# Episode: 1114/2000, Total Reward: 0
# Episode: 1115/2000, Total Reward: 0
# Episode: 1116/2000, Total Reward: 222
# Episode: 1117/2000, Total Reward: 0
# Episode: 1118/2000, Total Reward: 0
# Episode: 1119/2000, Total Reward: 0
# Episode: 1120/2000, Total Reward: 0
# Episode: 1121/2000, Total Reward: 0
# Episode: 1122/2000, Total Reward: 0
# Episode: 1123/2000, Total Reward: 0
# Episode: 1124/2000, Total Reward: 0
# Episode: 1125/2000, Total Reward: 0
# Episode: 1126/2000, Total Reward: 26
# Episode: 1127/2000, Total Reward: 0
# Episode: 1128/2000, Total Reward: 0
# Episode: 1129/2000, Total Reward: 0
# Episode: 1130/2000, Total Reward: 6
# Episode: 1131/2000, Total Reward: 0
# Episode: 1132/2000, Total Reward: 0
# Episode: 1133/2000, Total Reward: 0
# Episode: 1134/2000, Total Reward: 0
# Episode: 1135/2000, Total Reward: 0
# Episode: 1136/2000, Total Reward: 150
# Episode: 1137/2000, Total Reward: 0
# Episode: 1138/2000, Total Reward: 50
# Episode: 1139/2000, Total Reward: 0
# Episode: 1140/2000, Total Reward: 0
# Episode: 1141/2000, Total Reward: 0
# Episode: 1142/2000, Total Reward: 0
# Episode: 1143/2000, Total Reward: 0
# Episode: 1144/2000, Total Reward: 66
# Episode: 1145/2000, Total Reward: 0
# Episode: 1146/2000, Total Reward: 102
# Episode: 1147/2000, Total Reward: 0
# Episode: 1148/2000, Total Reward: 10
# Episode: 1149/2000, Total Reward: 0
# Episode: 1150/2000, Total Reward: 0
# Episode: 1151/2000, Total Reward: 0
# Episode: 1152/2000, Total Reward: 30
# Episode: 1153/2000, Total Reward: 0
# Episode: 1154/2000, Total Reward: 0
# Episode: 1155/2000, Total Reward: 0
# Episode: 1156/2000, Total Reward: 0
# Episode: 1157/2000, Total Reward: 76
# Episode: 1158/2000, Total Reward: 0
# Episode: 1159/2000, Total Reward: 0
# Episode: 1160/2000, Total Reward: 0
# Episode: 1161/2000, Total Reward: 0
# Episode: 1162/2000, Total Reward: 0
# Episode: 1163/2000, Total Reward: 0
# Episode: 1164/2000, Total Reward: 0
# Episode: 1165/2000, Total Reward: 0
# Episode: 1166/2000, Total Reward: 0
# Episode: 1167/2000, Total Reward: 0
# Episode: 1168/2000, Total Reward: 6
# Episode: 1169/2000, Total Reward: 0
# Episode: 1170/2000, Total Reward: 0
# Episode: 1171/2000, Total Reward: 0
# Episode: 1172/2000, Total Reward: 54
# Episode: 1173/2000, Total Reward: 0
# Episode: 1174/2000, Total Reward: 0
# Episode: 1175/2000, Total Reward: 0
# Episode: 1176/2000, Total Reward: 0
# Episode: 1177/2000, Total Reward: 0
# Episode: 1178/2000, Total Reward: 66
# Episode: 1179/2000, Total Reward: 0
# Episode: 1180/2000, Total Reward: 0
# Episode: 1181/2000, Total Reward: 0
# Episode: 1182/2000, Total Reward: 0
# Episode: 1183/2000, Total Reward: 50
# Episode: 1184/2000, Total Reward: 0
# Episode: 1185/2000, Total Reward: 10
# Episode: 1186/2000, Total Reward: 0
# Episode: 1187/2000, Total Reward: 0
# Episode: 1188/2000, Total Reward: 0
# Episode: 1189/2000, Total Reward: 0
# Episode: 1190/2000, Total Reward: 0
# Episode: 1191/2000, Total Reward: 0
# Episode: 1192/2000, Total Reward: 0
# Episode: 1193/2000, Total Reward: 0
# Episode: 1194/2000, Total Reward: 78
# Episode: 1195/2000, Total Reward: 0
# Episode: 1196/2000, Total Reward: 0
# Episode: 1197/2000, Total Reward: 0
# Episode: 1198/2000, Total Reward: 24
# Episode: 1199/2000, Total Reward: 0
# Episode: 1200/2000, Total Reward: 0
# Episode: 1201/2000, Total Reward: 6
# Episode: 1202/2000, Total Reward: 0
# Episode: 1203/2000, Total Reward: 0
# Episode: 1204/2000, Total Reward: 0
# Episode: 1205/2000, Total Reward: 0
# Episode: 1206/2000, Total Reward: 0
# Episode: 1207/2000, Total Reward: 0
# Episode: 1208/2000, Total Reward: 10
# Episode: 1209/2000, Total Reward: 0
# Episode: 1210/2000, Total Reward: 0
# Episode: 1211/2000, Total Reward: 138
# Episode: 1212/2000, Total Reward: 0
# Episode: 1213/2000, Total Reward: 0
# Episode: 1214/2000, Total Reward: 0
# Episode: 1215/2000, Total Reward: 0
# Episode: 1216/2000, Total Reward: 0
# Episode: 1217/2000, Total Reward: 6
# Episode: 1218/2000, Total Reward: 0
# Episode: 1219/2000, Total Reward: 0
# Episode: 1220/2000, Total Reward: 18
# Episode: 1221/2000, Total Reward: 0
# Episode: 1222/2000, Total Reward: 0
# Episode: 1223/2000, Total Reward: 0
# Episode: 1224/2000, Total Reward: 0
# Episode: 1225/2000, Total Reward: 18
# Episode: 1226/2000, Total Reward: 0
# Episode: 1227/2000, Total Reward: 0
# Episode: 1228/2000, Total Reward: 0
# Episode: 1229/2000, Total Reward: 0
# Episode: 1230/2000, Total Reward: 0
# Episode: 1231/2000, Total Reward: 0
# Episode: 1232/2000, Total Reward: 0
# Episode: 1233/2000, Total Reward: 0
# Episode: 1234/2000, Total Reward: 0
# Episode: 1235/2000, Total Reward: 0
# Episode: 1236/2000, Total Reward: 0
# Episode: 1237/2000, Total Reward: 0
# Episode: 1238/2000, Total Reward: 0
# Episode: 1239/2000, Total Reward: 38
# Episode: 1240/2000, Total Reward: 0
# Episode: 1241/2000, Total Reward: 70
# Episode: 1242/2000, Total Reward: 0
# Episode: 1243/2000, Total Reward: 0
# Episode: 1244/2000, Total Reward: 0
# Episode: 1245/2000, Total Reward: 6
# Episode: 1246/2000, Total Reward: 0
# Episode: 1247/2000, Total Reward: 0
# Episode: 1248/2000, Total Reward: 110
# Episode: 1249/2000, Total Reward: 0
# Episode: 1250/2000, Total Reward: 0
# Episode: 1251/2000, Total Reward: 66
# Episode: 1252/2000, Total Reward: 0
# Episode: 1253/2000, Total Reward: 62
# Episode: 1254/2000, Total Reward: 0
# Episode: 1255/2000, Total Reward: 0
# Episode: 1256/2000, Total Reward: 0
# Episode: 1257/2000, Total Reward: 0
# Episode: 1258/2000, Total Reward: 0
# Episode: 1259/2000, Total Reward: 0
# Episode: 1260/2000, Total Reward: 26
# Episode: 1261/2000, Total Reward: 0
# Episode: 1262/2000, Total Reward: 0
# Episode: 1263/2000, Total Reward: 0
# Episode: 1264/2000, Total Reward: 16
# Episode: 1265/2000, Total Reward: 0
# Episode: 1266/2000, Total Reward: 0
# Episode: 1267/2000, Total Reward: 0
# Episode: 1268/2000, Total Reward: 0
# Episode: 1269/2000, Total Reward: 0
# Episode: 1270/2000, Total Reward: 0
# Episode: 1271/2000, Total Reward: 38
# Episode: 1272/2000, Total Reward: 0
# Episode: 1273/2000, Total Reward: 0
# Episode: 1274/2000, Total Reward: 0
# Episode: 1275/2000, Total Reward: 70
# Episode: 1276/2000, Total Reward: 0
# Episode: 1277/2000, Total Reward: 0
# Episode: 1278/2000, Total Reward: 2
# Episode: 1279/2000, Total Reward: 0
# Episode: 1280/2000, Total Reward: 0
# Episode: 1281/2000, Total Reward: 0
# Episode: 1282/2000, Total Reward: 4
# Episode: 1283/2000, Total Reward: 0
# Episode: 1284/2000, Total Reward: 58
# Episode: 1285/2000, Total Reward: 0
# Episode: 1286/2000, Total Reward: 0
# Episode: 1287/2000, Total Reward: 0
# Episode: 1288/2000, Total Reward: 0
# Episode: 1289/2000, Total Reward: 64
# Episode: 1290/2000, Total Reward: 0
# Episode: 1291/2000, Total Reward: 0
# Episode: 1292/2000, Total Reward: 0
# Episode: 1293/2000, Total Reward: 86
# Episode: 1294/2000, Total Reward: 0
# Episode: 1295/2000, Total Reward: 0
# Episode: 1296/2000, Total Reward: 0
# Episode: 1297/2000, Total Reward: 0
# Episode: 1298/2000, Total Reward: 0
# Episode: 1299/2000, Total Reward: 0
# Episode: 1300/2000, Total Reward: 0
# Episode: 1301/2000, Total Reward: 0
# Episode: 1302/2000, Total Reward: 0
# Episode: 1303/2000, Total Reward: 30
# Episode: 1304/2000, Total Reward: 0
# Episode: 1305/2000, Total Reward: 42
# Episode: 1306/2000, Total Reward: 0
# Episode: 1307/2000, Total Reward: 0
# Episode: 1308/2000, Total Reward: 22
# Episode: 1309/2000, Total Reward: 0
# Episode: 1310/2000, Total Reward: 10
# Episode: 1311/2000, Total Reward: 0
# Episode: 1312/2000, Total Reward: 110
# Episode: 1313/2000, Total Reward: 0
# Episode: 1314/2000, Total Reward: 0
# Episode: 1315/2000, Total Reward: 0
# Episode: 1316/2000, Total Reward: 38
# Episode: 1317/2000, Total Reward: 0
# Episode: 1318/2000, Total Reward: 30
# Episode: 1319/2000, Total Reward: 0
# Episode: 1320/2000, Total Reward: 0
# Episode: 1321/2000, Total Reward: 0
# Episode: 1322/2000, Total Reward: 0
# Episode: 1323/2000, Total Reward: 0
# Episode: 1324/2000, Total Reward: 0
# Episode: 1325/2000, Total Reward: 38
# Episode: 1326/2000, Total Reward: 0
# Episode: 1327/2000, Total Reward: 0
# Episode: 1328/2000, Total Reward: 14
# Episode: 1329/2000, Total Reward: 0
# Episode: 1330/2000, Total Reward: 56
# Episode: 1331/2000, Total Reward: 0
# Episode: 1332/2000, Total Reward: 0
# Episode: 1333/2000, Total Reward: 0
# Episode: 1334/2000, Total Reward: 0
# Episode: 1335/2000, Total Reward: 0
# Episode: 1336/2000, Total Reward: 14
# Episode: 1337/2000, Total Reward: 0
# Episode: 1338/2000, Total Reward: 0
# Episode: 1339/2000, Total Reward: 0
# Episode: 1340/2000, Total Reward: 0
# Episode: 1341/2000, Total Reward: 0
# Episode: 1342/2000, Total Reward: 0
# Episode: 1343/2000, Total Reward: 0
# Episode: 1344/2000, Total Reward: 24
# Episode: 1345/2000, Total Reward: 0
# Episode: 1346/2000, Total Reward: 26
# Episode: 1347/2000, Total Reward: 0
# Episode: 1348/2000, Total Reward: 14
# Episode: 1349/2000, Total Reward: 0
# Episode: 1350/2000, Total Reward: 0
# Episode: 1351/2000, Total Reward: 0
# Episode: 1352/2000, Total Reward: 0
# Episode: 1353/2000, Total Reward: 0
# Episode: 1354/2000, Total Reward: 0
# Episode: 1355/2000, Total Reward: 0
# Episode: 1356/2000, Total Reward: 0
# ...
# Episode: 1560/2000, Total Reward: 54
# Episode: 1561/2000, Total Reward: 0
# Episode: 1562/2000, Total Reward: 0
# Episode: 1563/2000, Total Reward: 146
# Episode: 1564/2000, Total Reward: 0
# Episode: 1565/2000, Total Reward: 0
# Episode: 1566/2000, Total Reward: 0
# Episode: 1567/2000, Total Reward: 102
# Episode: 1568/2000, Total Reward: 0
# Episode: 1569/2000, Total Reward: 20
# Episode: 1570/2000, Total Reward: 0
# Episode: 1571/2000, Total Reward: 0
# Episode: 1572/2000, Total Reward: 0
# Episode: 1573/2000, Total Reward: 0
# Episode: 1574/2000, Total Reward: 0
# Episode: 1575/2000, Total Reward: 22
# Episode: 1576/2000, Total Reward: 0
# Episode: 1577/2000, Total Reward: 0
# Episode: 1578/2000, Total Reward: 0
# Episode: 1579/2000, Total Reward: 0
# Episode: 1580/2000, Total Reward: 0
# Episode: 1581/2000, Total Reward: 0
# Episode: 1582/2000, Total Reward: 0
# Episode: 1583/2000, Total Reward: 0
# Episode: 1584/2000, Total Reward: 0
# Episode: 1585/2000, Total Reward: 0
# Episode: 1586/2000, Total Reward: 54
# Episode: 1587/2000, Total Reward: 0
# Episode: 1588/2000, Total Reward: 0
# Episode: 1589/2000, Total Reward: 0
# Episode: 1590/2000, Total Reward: 0
# Episode: 1591/2000, Total Reward: 0
# Episode: 1592/2000, Total Reward: 0
# Episode: 1593/2000, Total Reward: 26
# Episode: 1594/2000, Total Reward: 0
# Episode: 1595/2000, Total Reward: 0
# Episode: 1596/2000, Total Reward: 126
# Episode: 1597/2000, Total Reward: 0
# Episode: 1598/2000, Total Reward: 0
# Episode: 1599/2000, Total Reward: 42
# Episode: 1600/2000, Total Reward: 0
# Episode: 1601/2000, Total Reward: 0
# Episode: 1602/2000, Total Reward: 0
# Episode: 1603/2000, Total Reward: 0
# Episode: 1604/2000, Total Reward: 14
# Episode: 1605/2000, Total Reward: 0
# Episode: 1606/2000, Total Reward: 0
# Episode: 1607/2000, Total Reward: 0
# Episode: 1608/2000, Total Reward: 0
# Episode: 1609/2000, Total Reward: 0
# Episode: 1610/2000, Total Reward: 0
# Episode: 1611/2000, Total Reward: 0
# Episode: 1612/2000, Total Reward: 0
# Episode: 1613/2000, Total Reward: 0
# Episode: 1614/2000, Total Reward: 0
# Episode: 1615/2000, Total Reward: 0
# Episode: 1616/2000, Total Reward: 0
# Episode: 1617/2000, Total Reward: 0
# Episode: 1618/2000, Total Reward: 0
# Episode: 1619/2000, Total Reward: 0
# Episode: 1620/2000, Total Reward: 38
# Episode: 1621/2000, Total Reward: 0
# Episode: 1622/2000, Total Reward: 10
# Episode: 1623/2000, Total Reward: 0
# Episode: 1624/2000, Total Reward: 0
# Episode: 1625/2000, Total Reward: 0
# Episode: 1626/2000, Total Reward: 0
# Episode: 1627/2000, Total Reward: 0
# Episode: 1628/2000, Total Reward: 0
# Episode: 1629/2000, Total Reward: 0
# Episode: 1630/2000, Total Reward: 0
# Episode: 1631/2000, Total Reward: 0
# Episode: 1632/2000, Total Reward: 10
# Episode: 1633/2000, Total Reward: 0
# Episode: 1634/2000, Total Reward: 0
# Episode: 1635/2000, Total Reward: 0
# Episode: 1636/2000, Total Reward: 22
# Episode: 1637/2000, Total Reward: 0
# Episode: 1638/2000, Total Reward: 0
# Episode: 1639/2000, Total Reward: 70
# Episode: 1640/2000, Total Reward: 0
# Episode: 1641/2000, Total Reward: 0
# Episode: 1642/2000, Total Reward: 0
# Episode: 1643/2000, Total Reward: 0
# Episode: 1644/2000, Total Reward: 14
# Episode: 1645/2000, Total Reward: 0
# Episode: 1646/2000, Total Reward: 50
# Episode: 1647/2000, Total Reward: 0
# Episode: 1648/2000, Total Reward: 0
# Episode: 1649/2000, Total Reward: 0
# Episode: 1650/2000, Total Reward: 26
# Episode: 1651/2000, Total Reward: 0
# Episode: 1652/2000, Total Reward: 0
# Episode: 1653/2000, Total Reward: 0
# Episode: 1654/2000, Total Reward: 0
# Episode: 1655/2000, Total Reward: 0
# Episode: 1656/2000, Total Reward: 48
# Episode: 1657/2000, Total Reward: 0
# Episode: 1658/2000, Total Reward: 22
# Episode: 1659/2000, Total Reward: 0
# Episode: 1660/2000, Total Reward: 0
# Episode: 1661/2000, Total Reward: 110
# Episode: 1662/2000, Total Reward: 0
# Episode: 1663/2000, Total Reward: 0
# Episode: 1664/2000, Total Reward: 46
# Episode: 1665/2000, Total Reward: 0
# Episode: 1666/2000, Total Reward: 76
# Episode: 1667/2000, Total Reward: 0
# Episode: 1668/2000, Total Reward: 42
# Episode: 1669/2000, Total Reward: 0
# Episode: 1670/2000, Total Reward: 0
# Episode: 1671/2000, Total Reward: 0
# Episode: 1672/2000, Total Reward: 70
# Episode: 1673/2000, Total Reward: 0
# Episode: 1674/2000, Total Reward: 0
# Episode: 1675/2000, Total Reward: 62
# Episode: 1676/2000, Total Reward: 0
# Episode: 1677/2000, Total Reward: 0
# Episode: 1678/2000, Total Reward: 0
# Episode: 1679/2000, Total Reward: 0
# Episode: 1680/2000, Total Reward: 0
# Episode: 1681/2000, Total Reward: 0
# Episode: 1682/2000, Total Reward: 0
# Episode: 1683/2000, Total Reward: 10
# Episode: 1684/2000, Total Reward: 0
# Episode: 1685/2000, Total Reward: 22
# Episode: 1686/2000, Total Reward: 0
# Episode: 1687/2000, Total Reward: 0
# Episode: 1688/2000, Total Reward: 0
# Episode: 1689/2000, Total Reward: 0
# Episode: 1690/2000, Total Reward: 12
# Episode: 1691/2000, Total Reward: 0
# Episode: 1692/2000, Total Reward: 34
# Episode: 1693/2000, Total Reward: 0
# Episode: 1694/2000, Total Reward: 0
# Episode: 1695/2000, Total Reward: 0
# Episode: 1696/2000, Total Reward: 0
# Episode: 1697/2000, Total Reward: 0
# Episode: 1698/2000, Total Reward: 218
# Episode: 1699/2000, Total Reward: 0
# Episode: 1700/2000, Total Reward: 0
# Episode: 1701/2000, Total Reward: 0
# Episode: 1702/2000, Total Reward: 0
# Episode: 1703/2000, Total Reward: 0
# Episode: 1704/2000, Total Reward: 94
# Episode: 1705/2000, Total Reward: 0
# Episode: 1706/2000, Total Reward: 0
# Episode: 1707/2000, Total Reward: 0
# Episode: 1708/2000, Total Reward: 0
# Episode: 1709/2000, Total Reward: 0
# Episode: 1710/2000, Total Reward: 0
# Episode: 1711/2000, Total Reward: 14
# Episode: 1712/2000, Total Reward: 0
# Episode: 1713/2000, Total Reward: 70
# Episode: 1714/2000, Total Reward: 0
# Episode: 1715/2000, Total Reward: 74
# Episode: 1716/2000, Total Reward: 0
# Episode: 1717/2000, Total Reward: 0
# Episode: 1718/2000, Total Reward: 0
# Episode: 1719/2000, Total Reward: 0
# Episode: 1720/2000, Total Reward: 6
# Episode: 1721/2000, Total Reward: 0
# Episode: 1722/2000, Total Reward: 0
# Episode: 1723/2000, Total Reward: 0
# Episode: 1724/2000, Total Reward: 6
# Episode: 1725/2000, Total Reward: 0
# Episode: 1726/2000, Total Reward: 0
# Episode: 1727/2000, Total Reward: 0
# Episode: 1728/2000, Total Reward: 54
# Episode: 1729/2000, Total Reward: 0
# Episode: 1730/2000, Total Reward: 0
# Episode: 1731/2000, Total Reward: 0
# Episode: 1732/2000, Total Reward: 94
# Episode: 1733/2000, Total Reward: 0
# Episode: 1734/2000, Total Reward: 86
# Episode: 1735/2000, Total Reward: 0
# Episode: 1736/2000, Total Reward: 0
# Episode: 1737/2000, Total Reward: 0
# Episode: 1738/2000, Total Reward: 0
# Episode: 1739/2000, Total Reward: 8
# Episode: 1740/2000, Total Reward: 0
# Episode: 1741/2000, Total Reward: 42
# Episode: 1742/2000, Total Reward: 0
# Episode: 1743/2000, Total Reward: 16
# Episode: 1744/2000, Total Reward: 0
# Episode: 1745/2000, Total Reward: 0
# Episode: 1746/2000, Total Reward: 0
# Episode: 1747/2000, Total Reward: 0
# Episode: 1748/2000, Total Reward: 66
# Episode: 1749/2000, Total Reward: 0
# Episode: 1750/2000, Total Reward: 0
# Episode: 1751/2000, Total Reward: 0
# Episode: 1752/2000, Total Reward: 14
# Episode: 1753/2000, Total Reward: 0
# Episode: 1754/2000, Total Reward: 0
# Episode: 1755/2000, Total Reward: 42
# Episode: 1756/2000, Total Reward: 0
# Episode: 1757/2000, Total Reward: 6
# Episode: 1758/2000, Total Reward: 0
# Episode: 1759/2000, Total Reward: 82
# Episode: 1760/2000, Total Reward: 0
# Episode: 1761/2000, Total Reward: 44
# Episode: 1762/2000, Total Reward: 0
# Episode: 1763/2000, Total Reward: 0
# Episode: 1764/2000, Total Reward: 0
# Episode: 1765/2000, Total Reward: 0
# Episode: 1766/2000, Total Reward: 0
# Episode: 1767/2000, Total Reward: 0
# Episode: 1768/2000, Total Reward: 0
# Episode: 1769/2000, Total Reward: 0
# Episode: 1770/2000, Total Reward: 48
# Episode: 1771/2000, Total Reward: 0
# Episode: 1772/2000, Total Reward: 0
# Episode: 1773/2000, Total Reward: 12
# Episode: 1774/2000, Total Reward: 0
# Episode: 1775/2000, Total Reward: 0
# Episode: 1776/2000, Total Reward: 0
# Episode: 1777/2000, Total Reward: 0
# Episode: 1778/2000, Total Reward: 66
# Episode: 1779/2000, Total Reward: 0
# Episode: 1780/2000, Total Reward: 0
# Episode: 1781/2000, Total Reward: 0
# Episode: 1782/2000, Total Reward: 0
# Episode: 1783/2000, Total Reward: 0
# Episode: 1784/2000, Total Reward: 0
# Episode: 1785/2000, Total Reward: 0
# Episode: 1786/2000, Total Reward: 0
# Episode: 1787/2000, Total Reward: 0
# Episode: 1788/2000, Total Reward: 0
# Episode: 1789/2000, Total Reward: 0
# Episode: 1790/2000, Total Reward: 0
# Episode: 1791/2000, Total Reward: 0
# Episode: 1792/2000, Total Reward: 0
# Episode: 1793/2000, Total Reward: 0
# Episode: 1794/2000, Total Reward: 0
# Episode: 1795/2000, Total Reward: 0
# Episode: 1796/2000, Total Reward: 0
# Episode: 1797/2000, Total Reward: 0
# Episode: 1798/2000, Total Reward: 0
# Episode: 1799/2000, Total Reward: 10
# Episode: 1800/2000, Total Reward: 0
# Episode: 1801/2000, Total Reward: 0
# Episode: 1802/2000, Total Reward: 0
# Episode: 1803/2000, Total Reward: 18
# Episode: 1804/2000, Total Reward: 0
# Episode: 1805/2000, Total Reward: 0
# Episode: 1806/2000, Total Reward: 0
# Episode: 1807/2000, Total Reward: 34
# Episode: 1808/2000, Total Reward: 0
# Episode: 1809/2000, Total Reward: 0
# Episode: 1810/2000, Total Reward: 36
# Episode: 1811/2000, Total Reward: 0
# Episode: 1812/2000, Total Reward: 0
# Episode: 1813/2000, Total Reward: 0
# Episode: 1814/2000, Total Reward: 0
# Episode: 1815/2000, Total Reward: 44
# Episode: 1816/2000, Total Reward: 0
# Episode: 1817/2000, Total Reward: 0
# Episode: 1818/2000, Total Reward: 0
# Episode: 1819/2000, Total Reward: 0
# Episode: 1820/2000, Total Reward: 0
# Episode: 1821/2000, Total Reward: 0
# Episode: 1822/2000, Total Reward: 0
# Episode: 1823/2000, Total Reward: 0
# Episode: 1824/2000, Total Reward: 0
# Episode: 1825/2000, Total Reward: 0
# Episode: 1826/2000, Total Reward: 0
# Episode: 1827/2000, Total Reward: 0
# Episode: 1828/2000, Total Reward: 18
# Episode: 1829/2000, Total Reward: 0
# Episode: 1830/2000, Total Reward: 0
# Episode: 1831/2000, Total Reward: 0
# Episode: 1832/2000, Total Reward: 0
# Episode: 1833/2000, Total Reward: 0
# Episode: 1834/2000, Total Reward: 0
# Episode: 1835/2000, Total Reward: 0
# Episode: 1836/2000, Total Reward: 6
# Episode: 1837/2000, Total Reward: 0
# Episode: 1838/2000, Total Reward: 62
# Episode: 1839/2000, Total Reward: 0
# Episode: 1840/2000, Total Reward: 14
# Episode: 1841/2000, Total Reward: 0
# Episode: 1842/2000, Total Reward: 0
# Episode: 1843/2000, Total Reward: 0
# Episode: 1844/2000, Total Reward: 46
# Episode: 1845/2000, Total Reward: 0
# Episode: 1846/2000, Total Reward: 4
# Episode: 1847/2000, Total Reward: 0
# Episode: 1848/2000, Total Reward: 0
# Episode: 1849/2000, Total Reward: 0
# Episode: 1850/2000, Total Reward: 0
# Episode: 1851/2000, Total Reward: 0
# Episode: 1852/2000, Total Reward: 46
# Episode: 1853/2000, Total Reward: 0
# Episode: 1854/2000, Total Reward: 0
# Episode: 1855/2000, Total Reward: 0
# Episode: 1856/2000, Total Reward: 0
# Episode: 1857/2000, Total Reward: 0
# Episode: 1858/2000, Total Reward: 0
# Episode: 1859/2000, Total Reward: 0
# Episode: 1860/2000, Total Reward: 0
# Episode: 1861/2000, Total Reward: 0
# Episode: 1862/2000, Total Reward: 0
# Episode: 1863/2000, Total Reward: 0
# Episode: 1864/2000, Total Reward: 0
# Episode: 1865/2000, Total Reward: 0
# Episode: 1866/2000, Total Reward: 0
# Episode: 1867/2000, Total Reward: 0
# Episode: 1868/2000, Total Reward: 0
# Episode: 1869/2000, Total Reward: 0
# Episode: 1870/2000, Total Reward: 62
# Episode: 1871/2000, Total Reward: 0
# Episode: 1872/2000, Total Reward: 0
# Episode: 1873/2000, Total Reward: 0
# Episode: 1874/2000, Total Reward: 0
# Episode: 1875/2000, Total Reward: 0
# Episode: 1876/2000, Total Reward: 0
# Episode: 1877/2000, Total Reward: 22
# Episode: 1878/2000, Total Reward: 0
# Episode: 1879/2000, Total Reward: 0
# Episode: 1880/2000, Total Reward: 0
# Episode: 1881/2000, Total Reward: 0
# Episode: 1882/2000, Total Reward: 0
# Episode: 1883/2000, Total Reward: 118
# Episode: 1884/2000, Total Reward: 0
# Episode: 1885/2000, Total Reward: 18
# Episode: 1886/2000, Total Reward: 0
# Episode: 1887/2000, Total Reward: 0
# Episode: 1888/2000, Total Reward: 0
# Episode: 1889/2000, Total Reward: 0
# Episode: 1890/2000, Total Reward: 0
# Episode: 1891/2000, Total Reward: 0
# Episode: 1892/2000, Total Reward: 50
# Episode: 1893/2000, Total Reward: 0
# Episode: 1894/2000, Total Reward: 0
# Episode: 1895/2000, Total Reward: 0
# Episode: 1896/2000, Total Reward: 0
# Episode: 1897/2000, Total Reward: 0
# Episode: 1898/2000, Total Reward: 0
# Episode: 1899/2000, Total Reward: 0
# Episode: 1900/2000, Total Reward: 30
# Episode: 1901/2000, Total Reward: 0
# Episode: 1902/2000, Total Reward: 0
# Episode: 1903/2000, Total Reward: 0
# Episode: 1904/2000, Total Reward: 2
# Episode: 1905/2000, Total Reward: 0
# Episode: 1906/2000, Total Reward: 0
# Episode: 1907/2000, Total Reward: 0
# Episode: 1908/2000, Total Reward: 0
# Episode: 1909/2000, Total Reward: 6
# Episode: 1910/2000, Total Reward: 0
# Episode: 1911/2000, Total Reward: 76
# Episode: 1912/2000, Total Reward: 0
# Episode: 1913/2000, Total Reward: 0
# Episode: 1914/2000, Total Reward: 0
# Episode: 1915/2000, Total Reward: 0
# Episode: 1916/2000, Total Reward: 6
# Episode: 1917/2000, Total Reward: 0
# Episode: 1918/2000, Total Reward: 0
# Episode: 1919/2000, Total Reward: 0
# Episode: 1920/2000, Total Reward: 0
# Episode: 1921/2000, Total Reward: 70
# Episode: 1922/2000, Total Reward: 0
# Episode: 1923/2000, Total Reward: 0
# Episode: 1924/2000, Total Reward: 36
# Episode: 1925/2000, Total Reward: 0
# Episode: 1926/2000, Total Reward: 0
# Episode: 1927/2000, Total Reward: 0
# Episode: 1928/2000, Total Reward: 0
# Episode: 1929/2000, Total Reward: 0
# Episode: 1930/2000, Total Reward: 0
# Episode: 1931/2000, Total Reward: 90
# Episode: 1932/2000, Total Reward: 0
# Episode: 1933/2000, Total Reward: 0
# Episode: 1934/2000, Total Reward: 0
# Episode: 1935/2000, Total Reward: 0
# Episode: 1936/2000, Total Reward: 106
# Episode: 1937/2000, Total Reward: 0
# Episode: 1938/2000, Total Reward: 0
# Episode: 1939/2000, Total Reward: 34
# Episode: 1940/2000, Total Reward: 0
# Episode: 1941/2000, Total Reward: 0
# Episode: 1942/2000, Total Reward: 106
# Episode: 1943/2000, Total Reward: 0
# Episode: 1944/2000, Total Reward: 0
# Episode: 1945/2000, Total Reward: 0
# Episode: 1946/2000, Total Reward: 0
# Episode: 1947/2000, Total Reward: 0
# Episode: 1948/2000, Total Reward: 0
# Episode: 1949/2000, Total Reward: 0
# Episode: 1950/2000, Total Reward: 0
# Episode: 1951/2000, Total Reward: 0
# Episode: 1952/2000, Total Reward: 0
# Episode: 1953/2000, Total Reward: 0
# Episode: 1954/2000, Total Reward: 10
# Episode: 1955/2000, Total Reward: 0
# Episode: 1956/2000, Total Reward: 0
# Episode: 1957/2000, Total Reward: 0
# Episode: 1958/2000, Total Reward: 0
# Episode: 1959/2000, Total Reward: 0
# Episode: 1960/2000, Total Reward: 70
# Episode: 1961/2000, Total Reward: 0
# Episode: 1962/2000, Total Reward: 0
# Episode: 1963/2000, Total Reward: 0
# Episode: 1964/2000, Total Reward: 0
# Episode: 1965/2000, Total Reward: 0
# Episode: 1966/2000, Total Reward: 0
# Episode: 1967/2000, Total Reward: 0
# Episode: 1968/2000, Total Reward: 0
# Episode: 1969/2000, Total Reward: 0
# Episode: 1970/2000, Total Reward: 56
# Episode: 1971/2000, Total Reward: 0
# Episode: 1972/2000, Total Reward: 32
# Episode: 1973/2000, Total Reward: 0
# Episode: 1974/2000, Total Reward: 0
# Episode: 1975/2000, Total Reward: 22
# Episode: 1976/2000, Total Reward: 0
# Episode: 1977/2000, Total Reward: 32
# Episode: 1978/2000, Total Reward: 0
# Episode: 1979/2000, Total Reward: 94
# Episode: 1980/2000, Total Reward: 0
# Episode: 1981/2000, Total Reward: 0
# Episode: 1982/2000, Total Reward: 0
# Episode: 1983/2000, Total Reward: 60
# Episode: 1984/2000, Total Reward: 0
# Episode: 1985/2000, Total Reward: 0
# Episode: 1986/2000, Total Reward: 0
# Episode: 1987/2000, Total Reward: 0
# Episode: 1988/2000, Total Reward: 0
# Episode: 1989/2000, Total Reward: 0
# Episode: 1990/2000, Total Reward: 0
# Episode: 1991/2000, Total Reward: 0
# Episode: 1992/2000, Total Reward: 0
# Episode: 1993/2000, Total Reward: 28
# Episode: 1994/2000, Total Reward: 0
# Episode: 1995/2000, Total Reward: 0
# Episode: 1996/2000, Total Reward: 14
# Episode: 1997/2000, Total Reward: 0
# Episode: 1998/2000, Total Reward: 0
# Episode: 1999/2000, Total Reward: 0
# Episode: 2000/2000, Total Reward: 20

# %% [markdown]
# 8. Save Model Weights

# %%
import torch

# Assuming `agent` is your trained model and `path_to_save` is the file path
torch.save(agent.q_network.state_dict(), './model-3/q_network_6000.pth')
torch.save(agent.target_network.state_dict(), './model-3/target_network_6000.pth')

# %% [markdown]
# 9. Load Model Weights

# %%
import torch

# Assuming `Agent` is your model class
agent.q_network = DQNCNN(env.action_space.n)  # Initialize the model architecture
agent.q_network.load_state_dict(torch.load('./model-3/q_network_6000.pth'))

agent.target_network = DQNCNN(env.action_space.n)  # Initialize the model architecture
agent.target_network.load_state_dict(torch.load('./model-3/target_network_6000.pth'))

# Ensure the models are in evaluation mode
agent.q_network.eval()
agent.target_network.eval()
# Out:
# C:\Users\Kaan\AppData\Local\Temp\ipykernel_14344\1626564088.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent.q_network.load_state_dict(torch.load('./model-3/q_network_6000.pth'))
# C:\Users\Kaan\AppData\Local\Temp\ipykernel_14344\1626564088.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent.target_network.load_state_dict(torch.load('./model-3/target_network_6000.pth'))
# DQNCNN(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=25600, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=4, bias=True)
# )

# %% [markdown]
# 10. Testing Loop

# %%
import matplotlib.pyplot as plt 

# Testing loop (after training)
num_test_episodes = 1
stack_size = STACK_SIZE
all_rewards = 0

for e in range(num_test_episodes):
    state_stack = deque(maxlen=stack_size)
    state, info = env.reset()

    # Initialize frame stack with the first frame
    frame = preprocess_frame(env.render())
    for _ in range(stack_size):
        state_stack.append(frame)

    done = False
    total_reward = 0

    while not done:
        # Render the frame
        # clear_output(wait=True)
        # plt.imshow(env.render())
        # plt.axis('off')  # Turn off the axis

        state = stack_frames(state_stack)

        # Use the trained model to select an action (no exploration during testing)
        action = agent.select_action(state, explore=False)  # No exploration in testing

        # Perform the action in the environment
        next_state, reward, done, _, _ = env.step(action)

        # Process the next state (frame) and update the frame stack
        next_frame = preprocess_frame(env.render())
        state_stack.append(next_frame)

        total_reward += reward

        # Update the plot with the new frame
        # plt.title(f"Test Episode: {e + 1}/{num_test_episodes}, Total Reward: {total_reward}")
        # plt.pause(0.001)  # Short pause to allow plot to update

    print(f"Test Episode: {e + 1}/{num_test_episodes}, Total Reward: {total_reward}")
    all_rewards += total_reward
print(f'avg score: {all_rewards/num_test_episodes}')
env.close()
# Out:
# Test Episode: 1/1, Total Reward: 58
# avg score: 58.0

# %% [markdown]
# # Visualizing Model
# Using a gradcam to see what the model looks at

# %%
class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.activations = None

        # Use only full backward hook (recommended)
        self.target_layer.register_forward_hook(self.save_activation)
        self.target_layer.register_full_backward_hook(self.save_gradient)

    def save_activation(self, module, input, output):
        self.activations = output.detach()

    def save_gradient(self, module, grad_input, grad_output):
        self.gradients = grad_output[0].detach()

    def generate(self, input_tensor, target_action_idx):
        self.model.eval()
        self.model.zero_grad()

        output = self.model(input_tensor)
        target = output[0, target_action_idx]
        target.backward()

        if self.gradients is None or self.activations is None:
            raise ValueError("Gradients or activations not captured.")

        # Global average pooling on gradients
        weights = self.gradients.mean(dim=(2, 3), keepdim=True)
        cam = (weights * self.activations).sum(dim=1, keepdim=True)
        cam = torch.relu(cam)

        # Normalize
        cam = cam.squeeze().cpu().numpy()
        cam -= cam.min()
        cam /= cam.max() + 1e-8

        return cam

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import torch

# Assume state_stack is a deque of 3 grayscale frames of shape [84, 84]
frame_stack = list(state_stack)  # Convert deque to list if necessary
device = torch.device("cpu")

# Stack frames into shape: [3, 84, 84]
frame_stack_np = np.stack(frame_stack, axis=0).astype(np.float32)

# Convert to torch tensor: shape [1, 3, 84, 84]
input_tensor = torch.from_numpy(frame_stack_np).unsqueeze(0).to(device)

# Forward pass & Grad-CAM
model = agent.q_network
gradcam = GradCAM(model, model.conv1)
q_values = model(input_tensor)
action = torch.argmax(q_values).item()
heatmap = gradcam.generate(input_tensor, action)

# Resize heatmap to match input
heatmap_resized = cv2.resize(heatmap, (84, 84))

# Plot each frame with its corresponding heatmap
plt.figure(figsize=(12, 4))

for idx in range(3):  # Loop through each frame in the stack
    plt.subplot(1, 3, idx + 1)
    base_img = frame_stack_np[idx]  # Pick the current frame in the stack
    plt.imshow(base_img, cmap='gray')
    plt.imshow(heatmap_resized, cmap='jet', alpha=0.5)
    plt.title(f"Grad-CAM for Action {action} - Frame {idx + 1}")
    plt.colorbar()
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
# The model still has a hard time understanding the fact that it is doing a sequential task. To make the model stronger I could look into RNN models.
